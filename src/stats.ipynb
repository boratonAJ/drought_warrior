# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import scipy as sp
from IPython.display import Image
#Image(filename='output1.png')

# %%
stats_list=pd.read_csv("../datasets/radio_audience.csv")

df = pd.DataFrame(stats_list)
df.head()
# Out:
#                Radio  Audience
# 0            Ukhozi    7294000
# 1  Umhlobo_Wenene_FM   5208000
# 2           Metro_FM   3968000
# 3          Lesedi_FM   3440000
# 4         Thobela_FM   2819000

# %%
Radio_station = stats_list['Radio']
Audience = stats_list['Audience']

# %% [markdown]
# ## Plotting Some Data
#
# We have our data read in and have completed some basic analysis. Let’s start plotting it.

# %%
Listeners = df[['Radio','Audience']]
Listeners.head()
# Out:
#                Radio  Audience
# 0            Ukhozi    7294000
# 1  Umhlobo_Wenene_FM   5208000
# 2           Metro_FM   3968000
# 3          Lesedi_FM   3440000
# 4         Thobela_FM   2819000

# %% [markdown]
# This representation has multiple lines for each Listener. In order to understand radio station patterns, let’s group all the radio stations by name. We can also look at the number of entries per audience to get an idea for the distribution.

# %%
Listener_group = Listeners.groupby('Radio')
Listener_group.size()
# Out:
# Radio
# 5FM                   1
# 702                   1
# 947                   1
# Algoa_FM              1
# CapeTalk              1
# Capricorn_FM          1
# Classic_FM_102.7      1
# East Coast Radio      1
# Gagasi_FM             1
# Goo_ Hope_FM          1
# Heart 104.9_FM        1
# Ikwekwezi_FM          1
# Jacaranda_FM          1
# KFM                   1
# Kaya_FM_95.9          1
# Lesedi_FM             1
# Ligwalagwala_FM       1
# Lotus_FM              1
# Metro_FM              1
# Motsweding_FM         1
# Munghana_Lonene_FM    1
# North_West_FM         1
# OFM                   1
# Phalaphala_FM         1
# Power_98.7            1
# RSG                   1
# Radio_2000            1
# SAfm                  1
# Smile_FM              1
# Thobela_FM            1
# Ukhozi                1
# Umhlobo_Wenene_FM     1
# Vuma_103_FM           1
# YFM_99.2              1
# trufm                 1
# dtype: int64

# %% [markdown]
# Now that we know what the data look like, it is very simple to create a quick bar chart plot. Using the IPython notebook, the graph will automatically display.

# %%
# http://pbpython.com/simple-graphing-pandas.html
my_plot = stats_list.plot(x='Radio', y='Audience', kind='bar', figsize=(10,6),fontsize=14, legend=None,title="The biggest radio stations in South Africa Per Audiences")
my_plot.set_xlabel("Radio Stations")
my_plot.set_ylabel("Audience")

# %% [markdown]
# ### Other interesting facts that come from the Broadcast Research Council in South Africa (BRC) datasets
# ##### Reference: https://businesstech.co.za/news/lifestyle/145469/this-is-how-many-people-are-listening-to-south-africas-most-popular-radio-stations/
#
# * South Africans listen to the radio for 4 hours and 6 minutes a day. The Free State has the longest tune-in time of 5 hours, while Gauteng listens for the shortest time at 3 and a half hours.
# * Sesotho and Swati listeners tune-in the longest at 4 hours and 36 minutes. English listeners tune-in for the shortest time at 3 hours 12 minutes.
# * More than half of listeners (52%) are considered ‘heavy listeners’ – tuning in for more than 20 hours a week.
# * 64% of listeners only listen to one station.
# * Portable radios are still the most widely-used device for listing to radio stations (76%) – followed by cellphones (37%), car radios (26%), desktop computers (8%) and laptops (2%).

# %% [markdown]
# ## DIGITAL MOBILE PENETRATION
# A data driven look at South Africa’s relationship with digital. Here we showcase the latest digital
# statistics in South Africa, with a focus on 4 main categories- Digital Growth, Digital Utilisation, Social
# Media, and Ecommerce. We provides additional insights.

# %% [markdown]
# ### DIGITAL GROWTH
#
# An overview of the South African population, and the growth statistics over the last year.
#
# * South Africa has a total population of 55,21 million people with Urbanisation rate of 66%
# * 28,6 million (52%) people utilise the Internet in some format. This has increased by 7% since Jan 2016.
# * 15 million users make use of social media platforms, with a 27% penetration rate of our total population
# * 13 million users do so purely from mobile, with a 24% penetration rate.

# %%
Image(filename='../datasets/digital_growth.png')

# %% [markdown]
# Reference: https://qwertydigital.co.za/wp-content/uploads/2017/08/Digital-Statistics-in-South-Africa-2017-Report.pdf
#
# This increased from Jan 2016, with an additional 2 million (15%) new active social media users, and 3 million (30%) new active social users on mobile.

# %% [markdown]
# ### DIGITAL PLATFORM UTILISATION
#
# Social Media vs TV We take note of how South African’s use Digital platforms, and what activities drive
# this consumption.
# * South Africa, and Africa, rely heavily on Mobile phones
# * one of the highest mobile penetration rates in the world
# * Mobile is responsible for over ¾ of all web traffic in South Africa
# * Since mobile brands focuse on content marketing, water saving awareness can be incorporate

# %%
Image(filename='../datasets/mobile_traffic.png')

# %% [markdown]
# Reference: https://qwertydigital.co.za/wp-content/uploads/2017/08/Digital-Statistics-in-South-Africa-2017-Report.pdf

# %% [markdown]
# ### SOCIAL MEDIA
#
# How many South African’s use Social Media, how often they use these platforms, and which platforms they hold
# dear. This is very important to note how South Africans consume content. The following showcases how much time an average South African will spend on various mediums of media. Therefore, we will use the game app to target the people by creating water saving awareness.

# %%
Image(filename='../datasets/digital_utiization.png')

# %% [markdown]
# Reference: https://qwertydigital.co.za/wp-content/uploads/2017/08/Digital-Statistics-in-South-Africa-2017-Report.pdf

# %% [markdown]
# ### Active Social Media Users
#
# The below graphs show how important social media is to the South African population. Social Media can offers a multitude of opportunities for water saving awareness.

# %%
Image(filename='../datasets/social_media.png')

# %% [markdown]
# Reference: https://qwertydigital.co.za/wp-content/uploads/2017/08/Digital-Statistics-in-South-Africa-2017-Report.pdf

# %% [markdown]
# With over 15 million users in South Africa alone, it’s clear that social media offers our population many benefits

# %% [markdown]
# ### E-COMMERCE
#
# Do South African’s utilise e-commerce? We provide insight into how often they browse and buy, and the
# drop-off rates between.

# %% [markdown]
# ### How incentive are leading people to behaviour change

# %%
Image(filename='../datasets/perception.png')
